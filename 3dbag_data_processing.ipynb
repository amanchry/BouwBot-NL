# %% [markdown]
# 3DBAG Data Preprocessing Script
# =================================
#
# The 3DBAG is an up-to-date data set containing 3D building models of the Netherlands. The 3DBAG is open data. It contains 3D models at multiple levels of detail, which are generated by combining two open data sets: the building data from the BAG and the height data from the AHN. The 3DBAG is updated regularly in order to remain up-to-date with the latest openly available building stock and elevation information.
#
# **Data source:** https://3dbag.nl/en/download
# **Dataset size:** ~19 GB (ZIP), ~111 GB uncompressed
#
#
# Overview
#
# This script performs a complete preprocessing pipeline to **clip the nationwide 3DBAG dataset
# to a smaller area of interest**, such as the city of **Utrecht**.
#
#
# Processing Steps
# 1. Downloads the 3DBAG GeoPackage ZIP
# 2. Inspects the zipped GeoPackage metadata (layers, CRS, geometry types, attributes)
# 3. Clips the building footprints layer (`pand`) to the Utrecht boundary
# 4. Writes the clipped data to a GeoPackage with a spatial index
# 5. Verifies the output by reading a small sample using GeoPandas
#
#
# Key design choices:
# - Uses GDAL Python bindings only
# - Reads the GeoPackage directly from ZIP using `/vsizip/`
# - Avoids loading large datasets into memory
# - Uses `/vsimem/` for temporary files (no disk clutter)
#
# Requirements:
# - Python
# - requests
# - tqdm
# - GDAL with Python bindings (osgeo)
# - geopandas

# %%
# -----------------------------
# Imports
# -----------------------------

from pathlib import Path
import requests
from osgeo import gdal, ogr, osr
import time
from tqdm import tqdm

# %%
# -----------------------------
# Static configuration
# -----------------------------

DATA_URL = "https://data.3dbag.nl/v20250903/3dbag_nl.gpkg.zip"
ZIP_FILE = "static/data/3dbag_nl.gpkg.zip"

BOUNDARY_FILE = "static/data/utrecht.geojson"
BOUNDARY_REPROJECTED = "static/data/utrecht_7415.geojson"
SOURCE_LAYER = "pand"

OUTPUT_GPKG = "static/data/utrecht_pand_clip.gpkg"
OUTPUT_LAYER = "pand_utrecht"

TARGET_EPSG = 7415  # Amersfoort / RD New + NAP height

# %%
# -----------------------------
# Download dataset (streaming)
# -----------------------------

def download_file(url: str, out_path: Path):
    if out_path.exists():
        print(f"✔ ZIP already exists: {out_path}")
        return

    print(f"⬇ Downloading:\n  {url}")

    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        total = int(r.headers.get("Content-Length", 0))

        with open(out_path, "wb") as f, tqdm(
            total=total,
            unit="B",
            unit_scale=True,
            unit_divisor=1024,
            desc="Downloading",
        ) as bar:
            for chunk in r.iter_content(chunk_size=8 * 1024 * 1024):  # 8 MB
                if chunk:
                    f.write(chunk)
                    bar.update(len(chunk))

    print("✔ Download complete")


# Call
download_file(DATA_URL, Path(ZIP_FILE))
# Out:
# ✔ ZIP already exists: static/data/3dbag_nl.gpkg.zip

# %%
# -----------------------------
# Inspect zipped GeoPackage
# -----------------------------

VSIZIP_PATH = f"/vsizip/{ZIP_FILE}"

def inspect_zipped_gpkg(vsizip_path: str):
    gdal.UseExceptions()
    ogr.UseExceptions()

    ds = gdal.OpenEx(vsizip_path, gdal.OF_VECTOR)
    if ds is None:
        raise RuntimeError(f"Could not open dataset: {vsizip_path}")

    print("\n==============================")
    print("DATASET INFORMATION")
    print("==============================")
    print("Path   :", vsizip_path)
    print("Driver :", ds.GetDriver().GetName())
    print("Layers :", ds.GetLayerCount())

    for i in range(ds.GetLayerCount()):
        layer = ds.GetLayerByIndex(i)
        defn = layer.GetLayerDefn()

        print("\n------------------------------")
        print(f"Layer {i + 1}: {layer.GetName()}")

        # Geometry
        geom_type = ogr.GeometryTypeToName(defn.GetGeomType())
        print("Geometry type :", geom_type)

        # Feature count
        print("Feature count :", layer.GetFeatureCount())

        # Extent
        extent = layer.GetExtent()
        if extent:
            print(f"Extent        : ({extent[0]:.3f}, {extent[2]:.3f}) - ({extent[1]:.3f}, {extent[3]:.3f})")

        # CRS
        srs = layer.GetSpatialRef()
        if srs:
            epsg = srs.GetAuthorityCode(None)
            if epsg:
                print("CRS           : EPSG:" + epsg)
            else:
                print("CRS           : Custom / Compound CRS")
        else:
            print("CRS           : None")

        # Geometry column
        print("Geometry col  :", layer.GetGeometryColumn() or "geom")

        # Attributes
        print("\nAttributes:")
        for j in range(defn.GetFieldCount()):
            field = defn.GetFieldDefn(j)
            print(
                f"  - {field.GetName()} "
                f"({field.GetFieldTypeName(field.GetType())})"
            )

    ds = None
    print("\n✅ Inspection complete.")


# Run
inspect_zipped_gpkg(VSIZIP_PATH)
# Out:
# ==============================
# DATASET INFORMATION
# ==============================
# Path   : /vsizip/static/data/3dbag_nl.gpkg.zip
# Driver : GPKG
# Layers : 7
#
# ------------------------------
# Layer 1: lod12_3d
# Geometry type : 3D Multi Polygon
# Feature count : 10783975
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - identificatie (String)
#   - b3_pand_deel_id (Integer64)
#   - labels (String)
#
# ------------------------------
# Layer 2: lod12_2d
# Geometry type : Polygon
# Feature count : 10783944
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - b3_h_50p (Real)
#   - b3_h_70p (Real)
#   - b3_h_max (Real)
#   - b3_h_min (Real)
#   - b3_dd_id (Integer64)
#   - identificatie (String)
#   - b3_pand_deel_id (Integer64)
#
# ------------------------------
# Layer 3: lod13_3d
# Geometry type : 3D Multi Polygon
# Feature count : 10783975
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - identificatie (String)
#   - b3_pand_deel_id (Integer64)
#   - labels (String)
#
# ------------------------------
# Layer 4: lod13_2d
# Geometry type : Polygon
# Feature count : 14141553
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - b3_h_50p (Real)
#   - b3_h_70p (Real)
#   - b3_h_max (Real)
#   - b3_h_min (Real)
#   - b3_dd_id (Integer64)
#   - identificatie (String)
#   - b3_pand_deel_id (Integer64)
#
# ------------------------------
# Layer 5: lod22_3d
# Geometry type : 3D Multi Polygon
# Feature count : 10783975
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - identificatie (String)
#   - b3_pand_deel_id (Integer64)
#   - labels (String)
#
# ------------------------------
# Layer 6: lod22_2d
# Geometry type : Polygon
# Feature count : 30111228
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - b3_azimut (Real)
#   - b3_h_50p (Real)
#   - b3_h_70p (Real)
#   - b3_h_max (Real)
#   - b3_h_min (Real)
#   - b3_hellingshoek (Real)
#   - b3_dd_id (Integer64)
#   - identificatie (String)
#   - b3_pand_deel_id (Integer64)
#
# ------------------------------
# Layer 7: pand
# Geometry type : Polygon
# Feature count : 10771547
# Extent        : (13603.331, 306900.406) - (277924.312, 612658.062)
# CRS           : EPSG:7415
# Geometry col  : geom
#
# Attributes:
#   - b3_bag_bag_overlap (Real)
#   - b3_bouwlagen (Real)
#   - b3_dak_type (String)
#   - b3_extrusie (String)
#   - b3_h_maaiveld (Real)
#   - b3_h_nok (Real)
#   - b3_is_glas_dak (Integer)
#   - b3_kas_warenhuis (Integer)
#   - b3_kwaliteitsindicator (Integer)
#   - b3_mutatie_ahn3_ahn4 (Integer)
#   - b3_mutatie_ahn4_ahn5 (Integer)
#   - b3_n_nok (Integer64)
#   - b3_n_vlakken (Integer64)
#   - b3_nodata_fractie_ahn3 (Real)
#   - b3_nodata_fractie_ahn4 (Real)
#   - b3_nodata_fractie_ahn5 (Real)
#   - b3_nodata_radius_ahn3 (Real)
#   - b3_nodata_radius_ahn4 (Real)
#   - b3_nodata_radius_ahn5 (Real)
#   - b3_opp_buitenmuur (Real)
#   - b3_opp_dak_plat (Real)
#   - b3_opp_dak_schuin (Real)
#   - b3_opp_grond (Real)
#   - b3_opp_scheidingsmuur (Real)
#   - b3_puntdichtheid_ahn3 (Real)
#   - b3_puntdichtheid_ahn4 (Real)
#   - b3_puntdichtheid_ahn5 (Real)
#   - b3_pw_bron (String)
#   - b3_pw_datum (Real)
#   - b3_pw_onvoldoende (Integer)
#   - b3_pw_selectie_reden (String)
#   - b3_rmse_lod12 (Real)
#   - b3_rmse_lod13 (Real)
#   - b3_rmse_lod22 (Real)
#   - b3_t_run (Real)
#   - b3_val3dity_lod12 (String)
#   - b3_val3dity_lod13 (String)
#   - b3_val3dity_lod22 (String)
#   - b3_volume_lod12 (Real)
#   - b3_volume_lod13 (Real)
#   - b3_volume_lod22 (Real)
#   - begingeldigheid (String)
#   - documentdatum (String)
#   - documentnummer (String)
#   - eindgeldigheid (String)
#   - eindregistratie (String)
#   - geconstateerd (Integer)
#   - identificatie (String)
#   - oorspronkelijkbouwjaar (Real)
#   - status (String)
#   - tijdstipeindregistratielv (String)
#   - tijdstipinactief (String)
#   - tijdstipinactieflv (String)
#   - tijdstipnietbaglv (String)
#   - tijdstipregistratie (String)
#   - tijdstipregistratielv (String)
#   - voorkomenidentificatie (Real)
#
# ✅ Inspection complete.

# %%
# -----------------------------
# Reproject boundary
# -----------------------------
def reproject_boundary(boundary_path: str, target_epsg: int) -> str:
    src = gdal.OpenEx(boundary_path, gdal.OF_VECTOR)

    srs = osr.SpatialReference()
    srs.ImportFromEPSG(target_epsg)


    gdal.VectorTranslate(
        BOUNDARY_REPROJECTED,
        src,
        options=gdal.VectorTranslateOptions(
            format="GeoJSON",
            dstSRS=srs.ExportToWkt(),
        )
    )

    src = None
    return BOUNDARY_REPROJECTED


# -----------------------------
# Clip pand layer
# -----------------------------
def clip_pand_layer(zip_path: Path, cutline_path: str):

    vsizip = f"/vsizip/{zip_path}"

    # Remove existing output
    if Path(OUTPUT_GPKG).exists():
        Path(OUTPUT_GPKG).unlink()

    gdal.VectorTranslate(
        OUTPUT_GPKG,
        vsizip,
        options=gdal.VectorTranslateOptions(
            format="GPKG",
            layers=[SOURCE_LAYER],
            options=[
                "-clipsrc", cutline_path,     # <-- IMPORTANT FIX
                "-nln", OUTPUT_LAYER,
            ],
            layerCreationOptions=[
                "SPATIAL_INDEX=YES"
            ],
        )
    )

# %%
# -----------------------------
# Main pipeline
# -----------------------------

def main():
    gdal.UseExceptions()
    ogr.UseExceptions()

    #  Reproject Utrecht boundary
    print("Reprojecting Utrecht boundary to EPSG:7415")
    reproject_boundary(BOUNDARY_FILE, TARGET_EPSG)

    # Clip buildings (pand)
    print("Clipping pand layer to Utrecht")
    clip_pand_layer(Path(ZIP_FILE), BOUNDARY_REPROJECTED)

    print(f"✅ Done! Output written to: {OUTPUT_GPKG}")


if __name__ == "__main__":
    main()
# Out:
# 🔄 Reprojecting Utrecht boundary to EPSG:7415
# ✂ Clipping pand layer to Utrecht
# ✅ Done! Output written to: static/data/utrecht_pand_clip.gpkg
# Warning 1: Layer 'pand_utrecht' has been declared with non-Z geometry type Polygon, but it does contain geometries with Z. Setting the Z=2 hint into gpkg_geometry_columns
# Warning 1: A geometry of type GEOMETRYCOLLECTION is inserted into layer pand_utrecht of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# ERROR 1: TopologyException: side location conflict at 141587.64101890757 440071.65598739497 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 129356.60816622103 454707.70726659981 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 115931.24622404104 468505.08130273438 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 130482.43863703762 475191.94568243442 0. This can occur if the input geometry is invalid.
# Warning 1: A geometry of type MULTIPOLYGON is inserted into layer pand_utrecht of geometry type POLYGON, which is not normally allowed by the GeoPackage specification, but the driver will however do it. To create a conformant GeoPackage, if using ogr2ogr, the -nlt option can be used to override the layer geometry type. This warning will no longer be emitted for this combination of layer and feature geometry type.
# ERROR 1: TopologyException: side location conflict at 136334.21564324043 432545.59808063455 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 117538.89116895443 440552.93097254675 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 119360.43895875885 448724.74568714772 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 130627.57256287619 446771.11043637147 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131586.63574472864 449285.96541473916 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 137761.40040204677 454409.47660818713 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 136779.11789800538 462864.61483587458 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 119342.63498928589 469347.35268871655 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 121720.60489129447 468256.3437636426 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 139576.74630519943 471462.15028490027 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 151846.17060800176 443092.50446203729 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 142365.37513076453 452860.27896979341 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 167955.12590067851 452477.22431783075 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 168330.4847010673 452853.36443541991 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 169069.00528708304 466223.68920959573 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 159986.28775832773 468463.19730123167 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 118035.52405387932 439720.99193965516 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 117952.38235157651 439740.91246033751 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 117611.39018369729 440831.66306855943 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 129911.22870275076 448524.60119994386 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 130669.86695885054 447083.66585327691 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131297.04610399881 447348.55909968703 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131500.68588073013 447324.97372003627 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 130715.33385191044 448692.08671695209 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 130881.15907818449 448510.74526987353 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131149.15986786914 447942.24318989343 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131252.13199626867 447936.50684079604 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131538.36575971587 447909.411940725 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 131601.47301636485 447803.85610777437 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 134703.64950758943 445055.62729829235 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 134622.94506366437 445376.62228628306 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 140238.31451434799 448754.02631832042 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 129706.29796501498 454609.54183871701 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 135161.90633474509 453045.31234845583 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 135204.31743613302 453497.49134108506 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 137521.98056859392 457923.77140904771 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: unable to assign free hole to a shell at 140828.8125 457746.375 0
# ERROR 1: TopologyException: side location conflict at 140829.63482624141 457662.73602084984 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 139509.4013251685 469544.00077760499 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 158745.79383296461 434239.40016592923 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 141627.54443138652 453472.41421993932 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 144186.97115823725 451357.27296566387 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 144205.17838472407 451791.7639710771 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 148581.87521939061 451910.56221917999 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 143310.23014253902 459746.2599672348 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 148392.4563512693 464213.3061216285 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 148320.35305059524 466066.5 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 148929.85461878192 466267.05405822763 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 148642.48632342322 466494.21752126463 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 156310.84869079117 466714.50451729476 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 159427.44023231257 465103.11925158394 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 168522.93189456261 460069.15760433389 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 168565.44664339474 461426.46158334706 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 148626.244813278 469579.51179979253 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 159098.2550517612 468699.69345076755 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 159780.16680244013 470024.65810662322 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 161916.8807439825 470014.24408195744 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 170987.89212206332 479234.44286261493 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 135023.59765625 456800.13937500003 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 136100.97929861245 456514.35153379425 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 136916.43830840191 455092.05549385014 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 136797.7204010337 455620.33219276415 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 136797.7204010337 455620.33219276415 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 137034.90849753449 456241.602674992 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 137496.95781068961 455938.5285557285 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 137475.87682661394 456696.75735100731 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 138318.21398998573 455263.33689557947 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 138306.36316158157 455150.43100871734 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 140502.09728483605 469372.01296106557 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 141530.63777791263 470662.76391990291 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 140274.06399715311 471849.6791874484 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 141765.75650842724 471180.68525592057 0. This can occur if the input geometry is invalid.
# ERROR 1: TopologyException: side location conflict at 161494.10986994111 470649.67585432658 0. This can occur if the input geometry is invalid.

# %%
# Read only first few rows to confirm output

import geopandas as gpd

gdf = gpd.read_file(OUTPUT_GPKG, layer=OUTPUT_LAYER, rows=5)

print("Columns:")
print(list(gdf.columns))

print("\nHead (attributes only):")
print(gdf.drop(columns="geometry").head())
# Out:
# Columns:
# ['b3_bag_bag_overlap', 'b3_bouwlagen', 'b3_dak_type', 'b3_extrusie', 'b3_h_maaiveld', 'b3_h_nok', 'b3_is_glas_dak', 'b3_kas_warenhuis', 'b3_kwaliteitsindicator', 'b3_mutatie_ahn3_ahn4', 'b3_mutatie_ahn4_ahn5', 'b3_n_nok', 'b3_n_vlakken', 'b3_nodata_fractie_ahn3', 'b3_nodata_fractie_ahn4', 'b3_nodata_fractie_ahn5', 'b3_nodata_radius_ahn3', 'b3_nodata_radius_ahn4', 'b3_nodata_radius_ahn5', 'b3_opp_buitenmuur', 'b3_opp_dak_plat', 'b3_opp_dak_schuin', 'b3_opp_grond', 'b3_opp_scheidingsmuur', 'b3_puntdichtheid_ahn3', 'b3_puntdichtheid_ahn4', 'b3_puntdichtheid_ahn5', 'b3_pw_bron', 'b3_pw_datum', 'b3_pw_onvoldoende', 'b3_pw_selectie_reden', 'b3_rmse_lod12', 'b3_rmse_lod13', 'b3_rmse_lod22', 'b3_t_run', 'b3_val3dity_lod12', 'b3_val3dity_lod13', 'b3_val3dity_lod22', 'b3_volume_lod12', 'b3_volume_lod13', 'b3_volume_lod22', 'begingeldigheid', 'documentdatum', 'documentnummer', 'eindgeldigheid', 'eindregistratie', 'geconstateerd', 'identificatie', 'oorspronkelijkbouwjaar', 'status', 'tijdstipeindregistratielv', 'tijdstipinactief', 'tijdstipinactieflv', 'tijdstipnietbaglv', 'tijdstipregistratie', 'tijdstipregistratielv', 'voorkomenidentificatie', 'geometry']
#
# Head (attributes only):
#    b3_bag_bag_overlap  b3_bouwlagen b3_dak_type     b3_extrusie  \
# 0                 0.0           NaN     slanted        standard
# 1                 0.0           NaN     slanted        standard
# 2                 0.0           NaN     slanted        standard
# 3                 0.0           NaN     unknown  lod11_fallback
# 4                 0.0           3.0     slanted        standard
#
#    b3_h_maaiveld   b3_h_nok  b3_is_glas_dak  b3_kas_warenhuis  \
# 0          0.909   4.521612           False             False
# 1          0.662   3.978173           False             False
# 2          1.220   4.430752           False             False
# 3         -0.710        NaN            True             False
# 4          1.015  10.040016           False             False
#
#    b3_kwaliteitsindicator  b3_mutatie_ahn3_ahn4  ...  \
# 0                    True                 False  ...
# 1                    True                  True  ...
# 2                    True                 False  ...
# 3                    True                  True  ...
# 4                    True                 False  ...
#
#                     identificatie  oorspronkelijkbouwjaar           status  \
# 0  NL.IMBAG.Pand.0317100000024100                  2021.0  Pand in gebruik
# 1  NL.IMBAG.Pand.0317100000024098                  2019.0  Pand in gebruik
# 2  NL.IMBAG.Pand.0317100000024102                  2008.0  Pand in gebruik
# 3  NL.IMBAG.Pand.0317100000007526                  1991.0  Pand in gebruik
# 4  NL.IMBAG.Pand.0317100000004788                  1991.0  Pand in gebruik
#
#    tijdstipeindregistratielv  tijdstipinactief  tijdstipinactieflv  \
# 0                       None              None                None
# 1                       None              None                None
# 2                       None              None                None
# 3                       None              None                None
# 4                       None              None                None
#
#    tijdstipnietbaglv   tijdstipregistratie  tijdstipregistratielv  \
# 0               None  2023-02-07T13:51:57Z   2023-02-07T13:51:59Z
# 1               None  2023-02-07T13:49:37Z   2023-02-07T13:49:38Z
# 2               None  2023-02-07T13:53:31Z   2023-02-07T13:53:32Z
# 3               None  2010-12-16T15:38:29Z   2010-12-17T13:53:16Z
# 4               None  2014-07-25T09:03:26Z   2014-07-25T09:30:55Z
#
#    voorkomenidentificatie
# 0                     2.0
# 1                     2.0
# 2                     2.0
# 3                     1.0
# 4                     2.0
#
# [5 rows x 57 columns]
